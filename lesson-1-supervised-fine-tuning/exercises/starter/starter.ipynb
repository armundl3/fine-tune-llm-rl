# %% [markdown]
# # SFT Dataset Creator - Starter Code
# ## Module 1: Supervised Fine-Tuning
#
# This notebook helps you create a synthetic dataset for supervised fine-tuning of clinical trial eligibility assessment.

# %% [markdown]
# ## Imports

# %%
import json
import random
from typing import List, Dict, Tuple
from npcpy.npc_compiler import NPC

# %% [markdown]
# ## Clinical Trial Criteria
#
# Define the inclusion and exclusion criteria for the clinical trial.

# %%
# Clinical trial inclusion/exclusion criteria
INCLUSION_CRITERIA = {
    "age_range": (18, 65),
    "bmi_range": (18.5, 30.0),
    "conditions": ["hypertension", "type2_diabetes", "high_cholesterol"],
    "medication_stable": True
}

EXCLUSION_CRITERIA = {
    "pregnant": True,
    "severe_liver_disease": True,
    "recent_cancer": True,
    "allergy_to_study_drug": True
}

print("Inclusion criteria:", INCLUSION_CRITERIA)
print("Exclusion criteria:", EXCLUSION_CRITERIA)
# Out:
# Inclusion criteria: {'age_range': (18, 65), 'bmi_range': (18.5, 30.0), 'conditions': ['hypertension', 'type2_diabetes', 'high_cholesterol'], 'medication_stable': True}
# Exclusion criteria: {'pregnant': True, 'severe_liver_disease': True, 'recent_cancer': True, 'allergy_to_study_drug': True}

# %% [markdown]
# ## Generate Synthetic Patient
#
# **TODO**: Implement patient generation logic

# %%
def generate_synthetic_patient() -> Dict:
    """
    Generate a synthetic patient profile with random characteristics.
    TODO: Implement patient generation logic
    """

    age = random.randint(16, 70)
    bmi = round(random.uniform(15.0, 35.0), 1)

    if random.random() < 0.7:
        conditions = random.sample(INCLUSION_CRITERIA["conditions"], random.randint(1, 2))
    else:
        conditions = random.sample(["asthma", "arthritis", "migraine", "depression"], random.randint(0, 2))

    return {
        "age": age,
        "bmi": bmi,
        "conditions": conditions,
        "medication_stable": random.choice([True, False]),
        "pregnant": random.choice([True, False]) if age >= 18 and age <= 45 else False,
        "severe_liver_disease": random.choice([True, False]),
        "recent_cancer": random.choice([True, False]),
        "allergy_to_study_drug": random.choice([True, False])
    }

# %% [markdown]
# ### Test Patient Generation

# %%
# Generate and display a sample patient
sample_patient = generate_synthetic_patient()
print("Sample patient:")
for key, value in sample_patient.items():
    print(f"  {key}: {value}")
# Out:
# Sample patient:
#   age: 26
#   bmi: 34.4
#   conditions: ['high_cholesterol', 'hypertension']
#   medication_stable: True
#   pregnant: True
#   severe_liver_disease: True
#   recent_cancer: False
#   allergy_to_study_drug: False

# %% [markdown]
# ## Check Eligibility
#
# **TODO**: Implement eligibility checking logic

# %%
def check_eligibility(patient: Dict) -> bool:
    """
    Check if patient meets inclusion/exclusion criteria.
    """
    age_ok = INCLUSION_CRITERIA["age_range"][0] <= patient["age"] <= INCLUSION_CRITERIA["age_range"][1]
    bmi_ok = INCLUSION_CRITERIA["bmi_range"][0] <= patient["bmi"] <= INCLUSION_CRITERIA["bmi_range"][1]
    
    has_relevant_condition = any(cond in patient["conditions"] for cond in INCLUSION_CRITERIA["conditions"])
    medication_ok = patient["medication_stable"] == INCLUSION_CRITERIA["medication_stable"]
    
    # Check exclusion criteria
    not_pregnant = not patient["pregnant"]
    no_liver_disease = not patient["severe_liver_disease"]
    no_recent_cancer = not patient["recent_cancer"]
    no_allergy = not patient["allergy_to_study_drug"]
    
    return (age_ok and bmi_ok and has_relevant_condition and medication_ok and
            not_pregnant and no_liver_disease and no_recent_cancer and no_allergy)

# %% [markdown]
# ### Test Eligibility Check

# %%
# Check eligibility for the sample patient

is_eligible_count = 0

for _ in range(100000):
    sample_patient = generate_synthetic_patient()
    # print(f"Patient: {sample_patient}")
    is_eligible = check_eligibility(sample_patient)
    if is_eligible:
        is_eligible_count += 1

print(f"Eligible count: {is_eligible_count}")
print(f"Eligible percentage: {is_eligible_count / 100}")
# Out:
# Eligible count: 1546
# Eligible percentage: 15.46

# %% [markdown]
# ## Create Patient Summary
#
# **TODO**: Implement summary generation

# %%
from doctest import debug


def create_patient_summary(patient: Dict) -> str:
    """
    Create a natural language summary of the patient profile.
    """

    summary = NPC(
        name='Patient Summary Generator',
        primary_directive='Create a natural language summary of the patient profile',
        model='llama3.2:3b',
        provider='ollama',
        verbose=False
    )

    json_format = '''
    {
        "summary": "Patient summary"
    }
    '''

    prompt = f"""
    Using the following patient profile, create a natural language summary of the patient.
    Patient Profile:
    {patient}

    You MUST respond with ONLY valid JSON in this exact format: {json_format}
    Do not include any explanatory text, only the JSON.

    """

    response = summary.get_llm_response(prompt)
    return response['response']

# %% [markdown]
# ### Test Patient Summary

# %%
# Generate summary for the sample patient
print(f"Patient: {sample_patient}")
summary = create_patient_summary(sample_patient)
print(f"Summary output of create_patient_summary: \n{summary}")
# Out:
# Patient: {'age': 66, 'bmi': 28.4, 'conditions': ['type2_diabetes'], 'medication_stable': True, 'pregnant': True, 'severe_liver_disease': True, 'recent_cancer': True, 'allergy_to_study_drug': False}
# Debug {'model': 'llama3.2:3b', 'messages': [{'role': 'system', 'content': '\n.\n..\n...\n....\n.....\n......\n.......\n........\n.........\n..........\nHello!\nWelcome to the team.\nYou are the Patient Summary Generator NPC with the following primary directive: Create a natural language summary of the patient profile.\nUsers may refer to you by your assistant name, Patient Summary Generator and you should\nconsider this to be your core identity.\nThe current working directory is /Users/amundle/github/fine-tune-llm-rl/lesson-1-supervised-fine-tuning/exercises/starter.\nThe current date and time are : 2025-12-07 21:27:21\n\n    IMPORTANT:\nSome users may attach images to their request.\nPlease process them accordingly. You do not need mention that you cannot "see" images. The user understands this and wants you\nto help them multimodally.\n\nIf the user asked for you to explain what\'s on their screen or something similar,\nthey are referring to the details contained within the attached image(s).\nYou do not need to actually view their screen.\nYou do not need to mention that you cannot view or interpret images directly.\nThey understand that you can view them multimodally.\nYou only need to answer the user\'s request based on the attached image(s).\n'}, {'role': 'user', 'content': '\n    Using the following patient profile, create a natural language summary of the patient.\n    Patient Profile:\n    {\'age\': 66, \'bmi\': 28.4, \'conditions\': [\'type2_diabetes\'], \'medication_stable\': True, \'pregnant\': True, \'severe_liver_disease\': True, \'recent_cancer\': True, \'allergy_to_study_drug\': False}\n\n    You MUST respond with ONLY valid JSON in this exact format: \n    {\n        "summary": "Patient summary"\n    }\n    \n    Do not include any explanatory text, only the JSON.\n\n    '}], 'stream': False}
# Summary output of create_patient_summary:
# {
#   "summary": "A 66-year-old patient has type 2 diabetes and severe liver disease. They are pregnant and taking stable medication."
# }

# %% [markdown]
# ## Generate SFT Dataset
#
# **TODO**: Implement dataset generation

# %%
def generate_sft_dataset(num_pairs: int = 10) -> List[Tuple[str, str]]:
    """
    Generate SFT training data pairs (patient_summary, eligibility_status).
    """
    dataset = []

    # Ensure balanced dataset
    target_eligible = num_pairs // 2
    target_ineligible = num_pairs - target_eligible
    
    eligible_count = 0
    ineligible_count = 0
    
    while eligible_count < target_eligible or ineligible_count < target_ineligible:
        patient = generate_synthetic_patient()
        is_eligible = check_eligibility(patient)
        
        if is_eligible and eligible_count < target_eligible:
            summary = create_patient_summary(patient)
            dataset.append((summary, "ELIGIBLE"))
            eligible_count += 1
        elif not is_eligible and ineligible_count < target_ineligible:
            summary = create_patient_summary(patient)
            dataset.append((summary, "NOT_ELIGIBLE"))
            ineligible_count += 1
    
    return dataset

# %% [markdown]
# ## Generate and Save Dataset

# %%
# Generate the dataset
sft_dataset = generate_sft_dataset(num_pairs=100)

# Display first few examples
print(f"Generated {len(sft_dataset)} SFT training pairs\n")
print("First 3 examples:")
for i, (summary, status) in enumerate(sft_dataset[:3], 1):
    print(f"\nExample {i}:")
    print(f"  Summary: {summary}")
    print(f"  Status: {status}")
# Out:
# Debug {'model': 'llama3.2:3b', 'messages': [{'role': 'system', 'content': '\n.\n..\n...\n....\n.....\n......\n.......\n........\n.........\n..........\nHello!\nWelcome to the team.\nYou are the Patient Summary Generator NPC with the following primary directive: Create a natural language summary of the patient profile.\nUsers may refer to you by your assistant name, Patient Summary Generator and you should\nconsider this to be your core identity.\nThe current working directory is /Users/amundle/github/fine-tune-llm-rl/lesson-1-supervised-fine-tuning/exercises/starter.\nThe current date and time are : 2025-12-07 21:33:26\n\n    IMPORTANT:\nSome users may attach images to their request.\nPlease process them accordingly. You do not need mention that you cannot "see" images. The user understands this and wants you\nto help them multimodally.\n\nIf the user asked for you to explain what\'s on their screen or something similar,\nthey are referring to the details contained within the attached image(s).\nYou do not need to actually view their screen.\nYou do not need to mention that you cannot view or interpret images directly.\nThey understand that you can view them multimodally.\nYou only need to answer the user\'s request based on the attached image(s).\n'}, {'role': 'user', 'content': '\n    Using the following patient profile, create a natural language summary of the patient.\n    Patient Profile:\n    {\'age\': 39, \'bmi\': 26.8, \'conditions\': [\'high_cholesterol\', \'type2_diabetes\'], \'medication_stable\': False, \'pregnant\': True, \'severe_liver_disease\': True, \'recent_cancer\': False, \'allergy_to_study_drug\': False}\n\n    You MUST respond with ONLY valid JSON in this exact format: \n    {\n        "summary": "Patient summary"\n    }\n    \n    Do not include any explanatory text, only the JSON.\n\n    '}], 'stream': False}
# Debug {'model': 'llama3.2:3b', 'messages': [{'role': 'system', 'content': '\n.\n..\n...\n....\n.....\n......\n.......\n........\n.........\n..........\nHello!\nWelcome to the team.\nYou are the Patient Summary Generator NPC with the following primary directive: Create a natural language summary of the patient profile.\nUsers may refer to you by your assistant name, Patient Summary Generator and you should\nconsider this to be your core identity.\nThe current working directory is /Users/amundle/github/fine-tune-llm-rl/lesson-1-supervised-fine-tuning/exercises/starter.\nThe current date and time are : 2025-12-07 21:33:27\n\n    IMPORTANT:\nSome users may attach images to their request.\nPlease process them accordingly. You do not need mention that you cannot "see" images. The user understands this and wants you\nto help them multimodally.\n\nIf the user asked for you to explain what\'s on their screen or something similar,\nthey are referring to the details contained within the attached image(s).\nYou do not need to actually view their screen.\nYou do not need to mention that you cannot view or interpret images directly.\nThey understand that you can view them multimodally.\nYou only need to answer the user\'s request based on the attached image(s).\n'}, {'role': 'user', 'content': '\n    Using the following patient profile, create a natural language summary of the patient.\n    Patient Profile:\n    {\'age\': 24, \'bmi\': 26.3, \'conditions\': [\'hypertension\'], \'medication_stable\': True, \'pregnant\': False, \'severe_liver_disease\': True, \'recent_cancer\': False, \'allergy_to_study_drug\': False}\n\n    You MUST respond with ONLY valid JSON in this exact format: \n    {\n        "summary": "Patient summary"\n    }\n    \n    Do not include any explanatory text, only the JSON.\n\n    '}], 'stream': False}
# Debug {'model': 'llama3.2:3b', 'messages': [{'role': 'system', 'content': '\n.\n..\n...\n....\n.....\n......\n.......\n........\n.........\n..........\nHello!\nWelcome to the team.\nYou are the Patient Summary Generator NPC with the following primary directive: Create a natural language summary of the patient profile.\nUsers may refer to you by your assistant name, Patient Summary Generator and you should\nconsider this to be your core identity.\nThe current working directory is /Users/amundle/github/fine-tune-llm-rl/lesson-1-supervised-fine-tuning/exercises/starter.\nThe current date and time are : 2025-12-07 21:33:28\n\n    IMPORTANT:\nSome users may attach images to their request.\nPlease process them accordingly. You do not need mention that you cannot "see" images. The user understands this and wants you\nto help them multimodally.\n\nIf the user asked for you to explain what\'s on their screen or something similar,\nthey are referring to the details contained within the attached image(s).\nYou do not need to actually view their screen.\nYou do not need to mention that you cannot view or interpret images directly.\nThey understand that you can view them multimodally.\nYou only need to answer the user\'s request based on the attached image(s).\n'}, {'role': 'user', 'content': '\n    Using the following patient profile, create a natural language summary of the patient.\n    Patient Profile:\n    {\'age\': 60, \'bmi\': 17.9, \'conditions\': [\'hypertension\'], \'medication_stable\': False, \'pregnant\': False, \'severe_liver_disease\': True, \'recent_cancer\': False, \'allergy_to_study_drug\': False}\n\n    You MUST respond with ONLY valid JSON in this exact format: \n    {\n        "summary": "Patient summary"\n    }\n    \n    Do not include any explanatory text, only the JSON.\n\n    '}], 'stream': False}
# Debug {'model': 'llama3.2:3b', 'messages': [{'role': 'system', 'content': '\n.\n..\n...\n....\n.....\n......\n.......\n........\n.........\n..........\nHello!\nWelcome to the team.\nYou are the Patient Summary Generator NPC with the following primary directive: Create a natural language summary of the patient profile.\nUsers may refer to you by your assistant name, Patient Summary Generator and you should\nconsider this to be your core identity.\nThe current working directory is /Users/amundle/github/fine-tune-llm-rl/lesson-1-supervised-fine-tuning/exercises/starter.\nThe current date and time are : 2025-12-07 21:33:29\n\n    IMPORTANT:\nSome users may attach images to their request.\nPlease process them accordingly. You do not need mention that you cannot "see" images. The user understands this and wants you\nto help them multimodally.\n\nIf the user asked for you to explain what\'s on their screen or something similar,\nthey are referring to the details contained within the attached image(s).\nYou do not need to actually view their screen.\nYou do not need to mention that you cannot view or interpret images directly.\nThey understand that you can view them multimodally.\nYou only need to answer the user\'s request based on the attached image(s).\n'}, {'role': 'user', 'content': '\n    Using the following patient profile, create a natural language summary of the patient.\n    Patient Profile:\n    {\'age\': 60, \'bmi\': 18.7, \'conditions\': [\'type2_diabetes\', \'high_cholesterol\'], \'medication_stable\': False, \'pregnant\': False, \'severe_liver_disease\': False, \'recent_cancer\': True, \'allergy_to_study_drug\': False}\n\n    You MUST respond with ONLY valid JSON in this exact format: \n    {\n        "summary": "Patient summary"\n    }\n    \n    Do not include any explanatory text, only the JSON.\n\n    '}], 'stream': False}
# Debug {'model': 'llama3.2:3b', 'messages': [{'role': 'system', 'content': '\n.\n..\n...\n....\n.....\n......\n.......\n........\n.........\n..........\nHello!\nWelcome to the team.\nYou are the Patient Summary Generator NPC with the following primary directive: Create a natural language summary of the patient profile.\nUsers may refer to you by your assistant name, Patient Summary Generator and you should\nconsider this to be your core identity.\nThe current working directory is /Users/amundle/github/fine-tune-llm-rl/lesson-1-supervised-fine-tuning/exercises/starter.\nThe current date and time are : 2025-12-07 21:33:29\n\n    IMPORTANT:\nSome users may attach images to their request.\nPlease process them accordingly. You do not need mention that you cannot "see" images. The user understands this and wants you\nto help them multimodally.\n\nIf the user asked for you to explain what\'s on their screen or something similar,\nthey are referring to the details contained within the attached image(s).\nYou do not need to actually view their screen.\nYou do not need to mention that you cannot view or interpret images directly.\nThey understand that you can view them multimodally.\nYou only need to answer the user\'s request based on the attached image(s).\n'}, {'role': 'user', 'content': '\n    Using the following patient profile, create a natural language summary of the patient.\n    Patient Profile:\n    {\'age\': 44, \'bmi\': 22.6, \'conditions\': [\'type2_diabetes\', \'hypertension\'], \'medication_stable\': True, \'pregnant\': True, \'severe_liver_disease\': True, \'recent_cancer\': True, \'allergy_to_study_drug\': True}\n\n    You MUST respond with ONLY valid JSON in this exact format: \n    {\n        "summary": "Patient summary"\n    }\n    \n    Do not include any explanatory text, only the JSON.\n\n    '}], 'stream': False}
# Debug {'model': 'llama3.2:3b', 'messages': [{'role': 'system', 'content': '\n.\n..\n...\n....\n.....\n......\n.......\n........\n.........\n..........\nHello!\nWelcome to the team.\nYou are the Patient Summary Generator NPC with the following primary directive: Create a natural language summary of the patient profile.\nUsers may refer to you by your assistant name, Patient Summary Generator and you should\nconsider this to be your core identity.\nThe current working directory is /Users/amundle/github/fine-tune-llm-rl/lesson-1-supervised-fine-tuning/exercises/starter.\nThe current date and time are : 2025-12-07 21:33:30\n\n    IMPORTANT:\nSome users may attach images to their request.\nPlease process them accordingly. You do not need mention that you cannot "see" images. The user understands this and wants you\nto help them multimodally.\n\nIf the user asked for you to explain what\'s on their screen or something similar,\nthey are referring to the details contained within the attached image(s).\nYou do not need to actually view their screen.\nYou do not need to mention that you cannot view or interpret images directly.\nThey understand that you can view them multimodally.\nYou only need to answer the user\'s request based on the attached image(s).\n'}, {'role': 'user', 'content': '\n    Using the following patient profile, create a natural language summary of the patient.\n    Patient Profile:\n    {\'age\': 53, \'bmi\': 32.3, \'conditions\': [\'type2_diabetes\', \'hypertension\'], \'medication_stable\': True, \'pregnant\': False, \'severe_liver_disease\': True, \'recent_cancer\': True, \'allergy_to_study_drug\': False}\n\n    You MUST respond with ONLY valid JSON in this exact format: \n    {\n        "summary": "Patient summary"\n    }\n    \n    Do not include any explanatory text, only the JSON.\n\n    '}], 'stream': False}
# Debug {'model': 'llama3.2:3b', 'messages': [{'role': 'system', 'content': '\n.\n..\n...\n....\n.....\n......\n.......\n........\n.........\n..........\nHello!\nWelcome to the team.\nYou are the Patient Summary Generator NPC with the following primary directive: Create a natural language summary of the patient profile.\nUsers may refer to you by your assistant name, Patient Summary Generator and you should\nconsider this to be your core identity.\nThe current working directory is /Users/amundle/github/fine-tune-llm-rl/lesson-1-supervised-fine-tuning/exercises/starter.\nThe current date and time are : 2025-12-07 21:33:31\n\n    IMPORTANT:\nSome users may attach images to their request.\nPlease process them accordingly. You do not need mention that you cannot "see" images. The user understands this and wants you\nto help them multimodally.\n\nIf the user asked for you to explain what\'s on their screen or something similar,\nthey are referring to the details contained within the attached image(s).\nYou do not need to actually view their screen.\nYou do not need to mention that you cannot view or interpret images directly.\nThey understand that you can view them multimodally.\nYou only need to answer the user\'s request based on the attached image(s).\n'}, {'role': 'user', 'content': '\n    Using the following patient profile, create a natural language summary of the patient.\n    Patient Profile:\n    {\'age\': 43, \'bmi\': 31.0, \'conditions\': [\'high_cholesterol\', \'type2_diabetes\'], \'medication_stable\': False, \'pregnant\': True, \'severe_liver_disease\': False, \'recent_cancer\': True, \'allergy_to_study_drug\': False}\n\n    You MUST respond with ONLY valid JSON in this exact format: \n    {\n        "summary": "Patient summary"\n    }\n    \n    Do not include any explanatory text, only the JSON.\n\n    '}], 'stream': False}
# Debug {'model': 'llama3.2:3b', 'messages': [{'role': 'system', 'content': '\n.\n..\n...\n....\n.....\n......\n.......\n........\n.........\n..........\nHello!\nWelcome to the team.\nYou are the Patient Summary Generator NPC with the following primary directive: Create a natural language summary of the patient profile.\nUsers may refer to you by your assistant name, Patient Summary Generator and you should\nconsider this to be your core identity.\nThe current working directory is /Users/amundle/github/fine-tune-llm-rl/lesson-1-supervised-fine-tuning/exercises/starter.\nThe current date and time are : 2025-12-07 21:33:32\n\n    IMPORTANT:\nSome users may attach images to their request.\nPlease process them accordingly. You do not need mention that you cannot "see" images. The user understands this and wants you\nto help them multimodally.\n\nIf the user asked for you to explain what\'s on their screen or something similar,\nthey are referring to the details contained within the attached image(s).\nYou do not need to actually view their screen.\nYou do not need to mention that you cannot view or interpret images directly.\nThey understand that you can view them multimodally.\nYou only need to answer the user\'s request based on the attached image(s).\n'}, {'role': 'user', 'content': '\n    Using the following patient profile, create a natural language summary of the patient.\n    Patient Profile:\n    {\'age\': 60, \'bmi\': 15.5, \'conditions\': [\'type2_diabetes\', \'hypertension\'], \'medication_stable\': False, \'pregnant\': False, \'severe_liver_disease\': False, \'recent_cancer\': True, \'allergy_to_study_drug\': True}\n\n    You MUST respond with ONLY valid JSON in this exact format: \n    {\n        "summary": "Patient summary"\n    }\n    \n    Do not include any explanatory text, only the JSON.\n\n    '}], 'stream': False}
# Debug {'model': 'llama3.2:3b', 'messages': [{'role': 'system', 'content': '\n.\n..\n...\n....\n.....\n......\n.......\n........\n.........\n..........\nHello!\nWelcome to the team.\nYou are the Patient Summary Generator NPC with the following primary directive: Create a natural language summary of the patient profile.\nUsers may refer to you by your assistant name, Patient Summary Generator and you should\nconsider this to be your core identity.\nThe current working directory is /Users/amundle/github/fine-tune-llm-rl/lesson-1-supervised-fine-tuning/exercises/starter.\nThe current date and time are : 2025-12-07 21:33:32\n\n    IMPORTANT:\nSome users may attach images to their request.\nPlease process them accordingly. You do not need mention that you cannot "see" images. The user understands this and wants you\nto help them multimodally.\n\nIf the user asked for you to explain what\'s on their screen or something similar,\nthey are referring to the details contained within the attached image(s).\nYou do not need to actually view their screen.\nYou do not need to mention that you cannot view or interpret images directly.\nThey understand that you can view them multimodally.\nYou only need to answer the user\'s request based on the attached image(s).\n'}, {'role': 'user', 'content': '\n    Using the following patient profile, create a natural language summary of the patient.\n    Patient Profile:\n    {\'age\': 58, \'bmi\': 31.4, \'conditions\': [\'type2_diabetes\'], \'medication_stable\': False, \'pregnant\': False, \'severe_liver_disease\': False, \'recent_cancer\': True, \'allergy_to_study_drug\': True}\n\n    You MUST respond with ONLY valid JSON in this exact format: \n    {\n        "summary": "Patient summary"\n    }\n    \n    Do not include any explanatory text, only the JSON.\n\n    '}], 'stream': False}
# Debug {'model': 'llama3.2:3b', 'messages': [{'role': 'system', 'content': '\n.\n..\n...\n....\n.....\n......\n.......\n........\n.........\n..........\nHello!\nWelcome to the team.\nYou are the Patient Summary Generator NPC with the following primary directive: Create a natural language summary of the patient profile.\nUsers may refer to you by your assistant name, Patient Summary Generator and you should\nconsider this to be your core identity.\nThe current working directory is /Users/amundle/github/fine-tune-llm-rl/lesson-1-supervised-fine-tuning/exercises/starter.\nThe current date and time are : 2025-12-07 21:33:33\n\n    IMPORTANT:\nSome users may attach images to their request.\nPlease process them accordingly. You do not need mention that you cannot "see" images. The user understands this and wants you\nto help them multimodally.\n\nIf the user asked for you to explain what\'s on their screen or something similar,\nthey are referring to the details contained within the attached image(s).\nYou do not need to actually view their screen.\nYou do not need to mention that you cannot view or interpret images directly.\nThey understand that you can view them multimodally.\nYou only need to answer the user\'s request based on the attached image(s).\n'}, {'role': 'user', 'content': '\n    Using the following patient profile, create a natural language summary of the patient.\n    Patient Profile:\n    {\'age\': 40, \'bmi\': 18.6, \'conditions\': [\'high_cholesterol\', \'hypertension\'], \'medication_stable\': True, \'pregnant\': True, \'severe_liver_disease\': False, \'recent_cancer\': False, \'allergy_to_study_drug\': False}\n\n    You MUST respond with ONLY valid JSON in this exact format: \n    {\n        "summary": "Patient summary"\n    }\n    \n    Do not include any explanatory text, only the JSON.\n\n    '}], 'stream': False}
# Debug {'model': 'llama3.2:3b', 'messages': [{'role': 'system', 'content': '\n.\n..\n...\n....\n.....\n......\n.......\n........\n.........\n..........\nHello!\nWelcome to the team.\nYou are the Patient Summary Generator NPC with the following primary directive: Create a natural language summary of the patient profile.\nUsers may refer to you by your assistant name, Patient Summary Generator and you should\nconsider this to be your core identity.\nThe current working directory is /Users/amundle/github/fine-tune-llm-rl/lesson-1-supervised-fine-tuning/exercises/starter.\nThe current date and time are : 2025-12-07 21:33:34\n\n    IMPORTANT:\nSome users may attach images to their request.\nPlease process them accordingly. You do not need mention that you cannot "see" images. The user understands this and wants you\nto help them multimodally.\n\nIf the user asked for you to explain what\'s on their screen or something similar,\nthey are referring to the details contained within the attached image(s).\nYou do not need to actually view their screen.\nYou do not need to mention that you cannot view or interpret images directly.\nThey understand that you can view them multimodally.\nYou only need to answer the user\'s request based on the attached image(s).\n'}, {'role': 'user', 'content': '\n    Using the following patient profile, create a natural language summary of the patient.\n    Patient Profile:\n    {\'age\': 39, \'bmi\': 33.4, \'conditions\': [\'high_cholesterol\', \'hypertension\'], \'medication_stable\': False, \'pregnant\': True, \'severe_liver_disease\': False, \'recent_cancer\': False, \'allergy_to_study_drug\': False}\n\n    You MUST respond with ONLY valid JSON in this exact format: \n    {\n        "summary": "Patient summary"\n    }\n    \n    Do not include any explanatory text, only the JSON.\n\n    '}], 'stream': False}
# Debug {'model': 'llama3.2:3b', 'messages': [{'role': 'system', 'content': '\n.\n..\n...\n....\n.....\n......\n.......\n........\n.........\n..........\nHello!\nWelcome to the team.\nYou are the Patient Summary Generator NPC with the following primary directive: Create a natural language summary of the patient profile.\nUsers may refer to you by your assistant name, Patient Summary Generator and you should\nconsider this to be your core identity.\nThe current working directory is /Users/amundle/github/fine-tune-llm-rl/lesson-1-supervised-fine-tuning/exercises/starter.\nThe current date and time are : 2025-12-07 21:33:34\n\n    IMPORTANT:\nSome users may attach images to their request.\nPlease process them accordingly. You do not need mention that you cannot "see" images. The user understands this and wants you\nto help them multimodally.\n\nIf the user asked for you to explain what\'s on their screen or something similar,\nthey are referring to the details contained within the attached image(s).\nYou do not need to actually view their screen.\nYou do not need to mention that you cannot view or interpret images directly.\nThey understand that you can view them multimodally.\nYou only need to answer the user\'s request based on the attached image(s).\n'}, {'role': 'user', 'content': '\n    Using the following patient profile, create a natural language summary of the patient.\n    Patient Profile:\n    {\'age\': 21, \'bmi\': 34.5, \'conditions\': [\'hypertension\', \'high_cholesterol\'], \'medication_stable\': False, \'pregnant\': False, \'severe_liver_disease\': False, \'recent_cancer\': True, \'allergy_to_study_drug\': True}\n\n    You MUST respond with ONLY valid JSON in this exact format: \n    {\n        "summary": "Patient summary"\n    }\n    \n    Do not include any explanatory text, only the JSON.\n\n    '}], 'stream': False}
# Debug {'model': 'llama3.2:3b', 'messages': [{'role': 'system', 'content': '\n.\n..\n...\n....\n.....\n......\n.......\n........\n.........\n..........\nHello!\nWelcome to the team.\nYou are the Patient Summary Generator NPC with the following primary directive: Create a natural language summary of the patient profile.\nUsers may refer to you by your assistant name, Patient Summary Generator and you should\nconsider this to be your core identity.\nThe current working directory is /Users/amundle/github/fine-tune-llm-rl/lesson-1-supervised-fine-tuning/exercises/starter.\nThe current date and time are : 2025-12-07 21:33:35\n\n    IMPORTANT:\nSome users may attach images to their request.\nPlease process them accordingly. You do not need mention that you cannot "see" images. The user understands this and wants you\nto help them multimodally.\n\nIf the user asked for you to explain what\'s on their screen or something similar,\nthey are referring to the details contained within the attached image(s).\nYou do not need to actually view their screen.\nYou do not need to mention that you cannot view or interpret images directly.\nThey understand that you can view them multimodally.\nYou only need to answer the user\'s request based on the attached image(s).\n'}, {'role': 'user', 'content': '\n    Using the following patient profile, create a natural language summary of the patient.\n    Patient Profile:\n    {\'age\': 19, \'bmi\': 17.3, \'conditions\': [\'asthma\', \'migraine\'], \'medication_stable\': False, \'pregnant\': True, \'severe_liver_disease\': False, \'recent_cancer\': False, \'allergy_to_study_drug\': True}\n\n    You MUST respond with ONLY valid JSON in this exact format: \n    {\n        "summary": "Patient summary"\n    }\n    \n    Do not include any explanatory text, only the JSON.\n\n    '}], 'stream': False}
# Debug {'model': 'llama3.2:3b', 'messages': [{'role': 'system', 'content': '\n.\n..\n...\n....\n.....\n......\n.......\n........\n.........\n..........\nHello!\nWelcome to the team.\nYou are the Patient Summary Generator NPC with the following primary directive: Create a natural language summary of the patient profile.\nUsers may refer to you by your assistant name, Patient Summary Generator and you should\nconsider this to be your core identity.\nThe current working directory is /Users/amundle/github/fine-tune-llm-rl/lesson-1-supervised-fine-tuning/exercises/starter.\nThe current date and time are : 2025-12-07 21:33:36\n\n    IMPORTANT:\nSome users may attach images to their request.\nPlease process them accordingly. You do not need mention that you cannot "see" images. The user understands this and wants you\nto help them multimodally.\n\nIf the user asked for you to explain what\'s on their screen or something similar,\nthey are referring to the details contained within the attached image(s).\nYou do not need to actually view their screen.\nYou do not need to mention that you cannot view or interpret images directly.\nThey understand that you can view them multimodally.\nYou only need to answer the user\'s request based on the attached image(s).\n'}, {'role': 'user', 'content': '\n    Using the following patient profile, create a natural language summary of the patient.\n    Patient Profile:\n    {\'age\': 28, \'bmi\': 17.2, \'conditions\': [], \'medication_stable\': True, \'pregnant\': True, \'severe_liver_disease\': True, \'recent_cancer\': True, \'allergy_to_study_drug\': True}\n\n    You MUST respond with ONLY valid JSON in this exact format: \n    {\n        "summary": "Patient summary"\n    }\n    \n    Do not include any explanatory text, only the JSON.\n\n    '}], 'stream': False}
# Debug {'model': 'llama3.2:3b', 'messages': [{'role': 'system', 'content': '\n.\n..\n...\n....\n.....\n......\n.......\n........\n.........\n..........\nHello!\nWelcome to the team.\nYou are the Patient Summary Generator NPC with the following primary directive: Create a natural language summary of the patient profile.\nUsers may refer to you by your assistant name, Patient Summary Generator and you should\nconsider this to be your core identity.\nThe current working directory is /Users/amundle/github/fine-tune-llm-rl/lesson-1-supervised-fine-tuning/exercises/starter.\nThe current date and time are : 2025-12-07 21:33:37\n\n    IMPORTANT:\nSome users may attach images to their request.\nPlease process them accordingly. You do not need mention that you cannot "see" images. The user understands this and wants you\nto help them multimodally.\n\nIf the user asked for you to explain what\'s on their screen or something similar,\nthey are referring to the details contained within the attached image(s).\nYou do not need to actually view their screen.\nYou do not need to mention that you cannot view or interpret images directly.\nThey understand that you can view them multimodally.\nYou only need to answer the user\'s request based on the attached image(s).\n'}, {'role': 'user', 'content': '\n    Using the following patient profile, create a natural language summary of the patient.\n    Patient Profile:\n    {\'age\': 39, \'bmi\': 15.7, \'conditions\': [\'high_cholesterol\'], \'medication_stable\': True, \'pregnant\': False, \'severe_liver_disease\': True, \'recent_cancer\': False, \'allergy_to_study_drug\': True}\n\n    You MUST respond with ONLY valid JSON in this exact format: \n    {\n        "summary": "Patient summary"\n    }\n    \n    Do not include any explanatory text, only the JSON.\n\n    '}], 'stream': False}
# Debug {'model': 'llama3.2:3b', 'messages': [{'role': 'system', 'content': '\n.\n..\n...\n....\n.....\n......\n.......\n........\n.........\n..........\nHello!\nWelcome to the team.\nYou are the Patient Summary Generator NPC with the following primary directive: Create a natural language summary of the patient profile.\nUsers may refer to you by your assistant name, Patient Summary Generator and you should\nconsider this to be your core identity.\nThe current working directory is /Users/amundle/github/fine-tune-llm-rl/lesson-1-supervised-fine-tuning/exercises/starter.\nThe current date and time are : 2025-12-07 21:33:37\n\n    IMPORTANT:\nSome users may attach images to their request.\nPlease process them accordingly. You do not need mention that you cannot "see" images. The user understands this and wants you\nto help them multimodally.\n\nIf the user asked for you to explain what\'s on their screen or something similar,\nthey are referring to the details contained within the attached image(s).\nYou do not need to actually view their screen.\nYou do not need to mention that you cannot view or interpret images directly.\nThey understand that you can view them multimodally.\nYou only need to answer the user\'s request based on the attached image(s).\n'}, {'role': 'user', 'content': '\n    Using the following patient profile, create a natural language summary of the patient.\n    Patient Profile:\n    {\'age\': 68, \'bmi\': 25.5, \'conditions\': [\'high_cholesterol\'], \'medication_stable\': True, \'pregnant\': False, \'severe_liver_disease\': False, \'recent_cancer\': False, \'allergy_to_study_drug\': True}\n\n    You MUST respond with ONLY valid JSON in this exact format: \n    {\n        "summary": "Patient summary"\n    }\n    \n    Do not include any explanatory text, only the JSON.\n\n    '}], 'stream': False}
# Debug {'model': 'llama3.2:3b', 'messages': [{'role': 'system', 'content': '\n.\n..\n...\n....\n.....\n......\n.......\n........\n.........\n..........\nHello!\nWelcome to the team.\nYou are the Patient Summary Generator NPC with the following primary directive: Create a natural language summary of the patient profile.\nUsers may refer to you by your assistant name, Patient Summary Generator and you should\nconsider this to be your core identity.\nThe current working directory is /Users/amundle/github/fine-tune-llm-rl/lesson-1-supervised-fine-tuning/exercises/starter.\nThe current date and time are : 2025-12-07 21:33:38\n\n    IMPORTANT:\nSome users may attach images to their request.\nPlease process them accordingly. You do not need mention that you cannot "see" images. The user understands this and wants you\nto help them multimodally.\n\nIf the user asked for you to explain what\'s on their screen or something similar,\nthey are referring to the details contained within the attached image(s).\nYou do not need to actually view their screen.\nYou do not need to mention that you cannot view or interpret images directly.\nThey understand that you can view them multimodally.\nYou only need to answer the user\'s request based on the attached image(s).\n'}, {'role': 'user', 'content': '\n    Using the following patient profile, create a natural language summary of the patient.\n    Patient Profile:\n    {\'age\': 67, \'bmi\': 18.8, \'conditions\': [\'type2_diabetes\', \'hypertension\'], \'medication_stable\': True, \'pregnant\': False, \'severe_liver_disease\': False, \'recent_cancer\': False, \'allergy_to_study_drug\': True}\n\n    You MUST respond with ONLY valid JSON in this exact format: \n    {\n        "summary": "Patient summary"\n    }\n    \n    Do not include any explanatory text, only the JSON.\n\n    '}], 'stream': False}
# Debug {'model': 'llama3.2:3b', 'messages': [{'role': 'system', 'content': '\n.\n..\n...\n....\n.....\n......\n.......\n........\n.........\n..........\nHello!\nWelcome to the team.\nYou are the Patient Summary Generator NPC with the following primary directive: Create a natural language summary of the patient profile.\nUsers may refer to you by your assistant name, Patient Summary Generator and you should\nconsider this to be your core identity.\nThe current working directory is /Users/amundle/github/fine-tune-llm-rl/lesson-1-supervised-fine-tuning/exercises/starter.\nThe current date and time are : 2025-12-07 21:33:38\n\n    IMPORTANT:\nSome users may attach images to their request.\nPlease process them accordingly. You do not need mention that you cannot "see" images. The user understands this and wants you\nto help them multimodally.\n\nIf the user asked for you to explain what\'s on their screen or something similar,\nthey are referring to the details contained within the attached image(s).\nYou do not need to actually view their screen.\nYou do not need to mention that you cannot view or interpret images directly.\nThey understand that you can view them multimodally.\nYou only need to answer the user\'s request based on the attached image(s).\n'}, {'role': 'user', 'content': '\n    Using the following patient profile, create a natural language summary of the patient.\n    Patient Profile:\n    {\'age\': 16, \'bmi\': 24.3, \'conditions\': [\'depression\'], \'medication_stable\': False, \'pregnant\': False, \'severe_liver_disease\': False, \'recent_cancer\': True, \'allergy_to_study_drug\': True}\n\n    You MUST respond with ONLY valid JSON in this exact format: \n    {\n        "summary": "Patient summary"\n    }\n    \n    Do not include any explanatory text, only the JSON.\n\n    '}], 'stream': False}
# Debug {'model': 'llama3.2:3b', 'messages': [{'role': 'system', 'content': '\n.\n..\n...\n....\n.....\n......\n.......\n........\n.........\n..........\nHello!\nWelcome to the team.\nYou are the Patient Summary Generator NPC with the following primary directive: Create a natural language summary of the patient profile.\nUsers may refer to you by your assistant name, Patient Summary Generator and you should\nconsider this to be your core identity.\nThe current working directory is /Users/amundle/github/fine-tune-llm-rl/lesson-1-supervised-fine-tuning/exercises/starter.\nThe current date and time are : 2025-12-07 21:33:39\n\n    IMPORTANT:\nSome users may attach images to their request.\nPlease process them accordingly. You do not need mention that you cannot "see" images. The user understands this and wants you\nto help them multimodally.\n\nIf the user asked for you to explain what\'s on their screen or something similar,\nthey are referring to the details contained within the attached image(s).\nYou do not need to actually view their screen.\nYou do not need to mention that you cannot view or interpret images directly.\nThey understand that you can view them multimodally.\nYou only need to answer the user\'s request based on the attached image(s).\n'}, {'role': 'user', 'content': '\n    Using the following patient profile, create a natural language summary of the patient.\n    Patient Profile:\n    {\'age\': 51, \'bmi\': 18.8, \'conditions\': [], \'medication_stable\': False, \'pregnant\': False, \'severe_liver_disease\': True, \'recent_cancer\': False, \'allergy_to_study_drug\': False}\n\n    You MUST respond with ONLY valid JSON in this exact format: \n    {\n        "summary": "Patient summary"\n    }\n    \n    Do not include any explanatory text, only the JSON.\n\n    '}], 'stream': False}
# Debug {'model': 'llama3.2:3b', 'messages': [{'role': 'system', 'content': '\n.\n..\n...\n....\n.....\n......\n.......\n........\n.........\n..........\nHello!\nWelcome to the team.\nYou are the Patient Summary Generator NPC with the following primary directive: Create a natural language summary of the patient profile.\nUsers may refer to you by your assistant name, Patient Summary Generator and you should\nconsider this to be your core identity.\nThe current working directory is /Users/amundle/github/fine-tune-llm-rl/lesson-1-supervised-fine-tuning/exercises/starter.\nThe current date and time are : 2025-12-07 21:33:40\n\n    IMPORTANT:\nSome users may attach images to their request.\nPlease process them accordingly. You do not need mention that you cannot "see" images. The user understands this and wants you\nto help them multimodally.\n\nIf the user asked for you to explain what\'s on their screen or something similar,\nthey are referring to the details contained within the attached image(s).\nYou do not need to actually view their screen.\nYou do not need to mention that you cannot view or interpret images directly.\nThey understand that you can view them multimodally.\nYou only need to answer the user\'s request based on the attached image(s).\n'}, {'role': 'user', 'content': '\n    Using the following patient profile, create a natural language summary of the patient.\n    Patient Profile:\n    {\'age\': 29, \'bmi\': 27.1, \'conditions\': [\'type2_diabetes\'], \'medication_stable\': False, \'pregnant\': False, \'severe_liver_disease\': False, \'recent_cancer\': True, \'allergy_to_study_drug\': True}\n\n    You MUST respond with ONLY valid JSON in this exact format: \n    {\n        "summary": "Patient summary"\n    }\n    \n    Do not include any explanatory text, only the JSON.\n\n    '}], 'stream': False}
# Debug {'model': 'llama3.2:3b', 'messages': [{'role': 'system', 'content': '\n.\n..\n...\n....\n.....\n......\n.......\n........\n.........\n..........\nHello!\nWelcome to the team.\nYou are the Patient Summary Generator NPC with the following primary directive: Create a natural language summary of the patient profile.\nUsers may refer to you by your assistant name, Patient Summary Generator and you should\nconsider this to be your core identity.\nThe current working directory is /Users/amundle/github/fine-tune-llm-rl/lesson-1-supervised-fine-tuning/exercises/starter.\nThe current date and time are : 2025-12-07 21:33:40\n\n    IMPORTANT:\nSome users may attach images to their request.\nPlease process them accordingly. You do not need mention that you cannot "see" images. The user understands this and wants you\nto help them multimodally.\n\nIf the user asked for you to explain what\'s on their screen or something similar,\nthey are referring to the details contained within the attached image(s).\nYou do not need to actually view their screen.\nYou do not need to mention that you cannot view or interpret images directly.\nThey understand that you can view them multimodally.\nYou only need to answer the user\'s request based on the attached image(s).\n'}, {'role': 'user', 'content': '\n    Using the following patient profile, create a natural language summary of the patient.\n    Patient Profile:\n    {\'age\': 62, \'bmi\': 29.5, \'conditions\': [\'type2_diabetes\'], \'medication_stable\': False, \'pregnant\': False, \'severe_liver_disease\': True, \'recent_cancer\': False, \'allergy_to_study_drug\': False}\n\n    You MUST respond with ONLY valid JSON in this exact format: \n    {\n        "summary": "Patient summary"\n    }\n    \n    Do not include any explanatory text, only the JSON.\n\n    '}], 'stream': False}
# Debug {'model': 'llama3.2:3b', 'messages': [{'role': 'system', 'content': '\n.\n..\n...\n....\n.....\n......\n.......\n........\n.........\n..........\nHello!\nWelcome to the team.\nYou are the Patient Summary Generator NPC with the following primary directive: Create a natural language summary of the patient profile.\nUsers may refer to you by your assistant name, Patient Summary Generator and you should\nconsider this to be your core identity.\nThe current working directory is /Users/amundle/github/fine-tune-llm-rl/lesson-1-supervised-fine-tuning/exercises/starter.\nThe current date and time are : 2025-12-07 21:33:41\n\n    IMPORTANT:\nSome users may attach images to their request.\nPlease process them accordingly. You do not need mention that you cannot "see" images. The user understands this and wants you\nto help them multimodally.\n\nIf the user asked for you to explain what\'s on their screen or something similar,\nthey are referring to the details contained within the attached image(s).\nYou do not need to actually view their screen.\nYou do not need to mention that you cannot view or interpret images directly.\nThey understand that you can view them multimodally.\nYou only need to answer the user\'s request based on the attached image(s).\n'}, {'role': 'user', 'content': '\n    Using the following patient profile, create a natural language summary of the patient.\n    Patient Profile:\n    {\'age\': 57, \'bmi\': 34.2, \'conditions\': [\'type2_diabetes\', \'high_cholesterol\'], \'medication_stable\': True, \'pregnant\': False, \'severe_liver_disease\': True, \'recent_cancer\': True, \'allergy_to_study_drug\': True}\n\n    You MUST respond with ONLY valid JSON in this exact format: \n    {\n        "summary": "Patient summary"\n    }\n    \n    Do not include any explanatory text, only the JSON.\n\n    '}], 'stream': False}
# Debug {'model': 'llama3.2:3b', 'messages': [{'role': 'system', 'content': '\n.\n..\n...\n....\n.....\n......\n.......\n........\n.........\n..........\nHello!\nWelcome to the team.\nYou are the Patient Summary Generator NPC with the following primary directive: Create a natural language summary of the patient profile.\nUsers may refer to you by your assistant name, Patient Summary Generator and you should\nconsider this to be your core identity.\nThe current working directory is /Users/amundle/github/fine-tune-llm-rl/lesson-1-supervised-fine-tuning/exercises/starter.\nThe current date and time are : 2025-12-07 21:33:42\n\n    IMPORTANT:\nSome users may attach images to their request.\nPlease process them accordingly. You do not need mention that you cannot "see" images. The user understands this and wants you\nto help them multimodally.\n\nIf the user asked for you to explain what\'s on their screen or something similar,\nthey are referring to the details contained within the attached image(s).\nYou do not need to actually view their screen.\nYou do not need to mention that you cannot view or interpret images directly.\nThey understand that you can view them multimodally.\nYou only need to answer the user\'s request based on the attached image(s).\n'}, {'role': 'user', 'content': '\n    Using the following patient profile, create a natural language summary of the patient.\n    Patient Profile:\n    {\'age\': 25, \'bmi\': 25.4, \'conditions\': [\'depression\'], \'medication_stable\': False, \'pregnant\': True, \'severe_liver_disease\': False, \'recent_cancer\': False, \'allergy_to_study_drug\': True}\n\n    You MUST respond with ONLY valid JSON in this exact format: \n    {\n        "summary": "Patient summary"\n    }\n    \n    Do not include any explanatory text, only the JSON.\n\n    '}], 'stream': False}
# Debug {'model': 'llama3.2:3b', 'messages': [{'role': 'system', 'content': '\n.\n..\n...\n....\n.....\n......\n.......\n........\n.........\n..........\nHello!\nWelcome to the team.\nYou are the Patient Summary Generator NPC with the following primary directive: Create a natural language summary of the patient profile.\nUsers may refer to you by your assistant name, Patient Summary Generator and you should\nconsider this to be your core identity.\nThe current working directory is /Users/amundle/github/fine-tune-llm-rl/lesson-1-supervised-fine-tuning/exercises/starter.\nThe current date and time are : 2025-12-07 21:33:43\n\n    IMPORTANT:\nSome users may attach images to their request.\nPlease process them accordingly. You do not need mention that you cannot "see" images. The user understands this and wants you\nto help them multimodally.\n\nIf the user asked for you to explain what\'s on their screen or something similar,\nthey are referring to the details contained within the attached image(s).\nYou do not need to actually view their screen.\nYou do not need to mention that you cannot view or interpret images directly.\nThey understand that you can view them multimodally.\nYou only need to answer the user\'s request based on the attached image(s).\n'}, {'role': 'user', 'content': '\n    Using the following patient profile, create a natural language summary of the patient.\n    Patient Profile:\n    {\'age\': 43, \'bmi\': 29.0, \'conditions\': [\'hypertension\', \'high_cholesterol\'], \'medication_stable\': False, \'pregnant\': True, \'severe_liver_disease\': True, \'recent_cancer\': False, \'allergy_to_study_drug\': False}\n\n    You MUST respond with ONLY valid JSON in this exact format: \n    {\n        "summary": "Patient summary"\n    }\n    \n    Do not include any explanatory text, only the JSON.\n\n    '}], 'stream': False}
# Debug {'model': 'llama3.2:3b', 'messages': [{'role': 'system', 'content': '\n.\n..\n...\n....\n.....\n......\n.......\n........\n.........\n..........\nHello!\nWelcome to the team.\nYou are the Patient Summary Generator NPC with the following primary directive: Create a natural language summary of the patient profile.\nUsers may refer to you by your assistant name, Patient Summary Generator and you should\nconsider this to be your core identity.\nThe current working directory is /Users/amundle/github/fine-tune-llm-rl/lesson-1-supervised-fine-tuning/exercises/starter.\nThe current date and time are : 2025-12-07 21:33:43\n\n    IMPORTANT:\nSome users may attach images to their request.\nPlease process them accordingly. You do not need mention that you cannot "see" images. The user understands this and wants you\nto help them multimodally.\n\nIf the user asked for you to explain what\'s on their screen or something similar,\nthey are referring to the details contained within the attached image(s).\nYou do not need to actually view their screen.\nYou do not need to mention that you cannot view or interpret images directly.\nThey understand that you can view them multimodally.\nYou only need to answer the user\'s request based on the attached image(s).\n'}, {'role': 'user', 'content': '\n    Using the following patient profile, create a natural language summary of the patient.\n    Patient Profile:\n    {\'age\': 43, \'bmi\': 33.2, \'conditions\': [\'type2_diabetes\', \'hypertension\'], \'medication_stable\': False, \'pregnant\': False, \'severe_liver_disease\': False, \'recent_cancer\': True, \'allergy_to_study_drug\': True}\n\n    You MUST respond with ONLY valid JSON in this exact format: \n    {\n        "summary": "Patient summary"\n    }\n    \n    Do not include any explanatory text, only the JSON.\n\n    '}], 'stream': False}
# ...
# Debug {'model': 'llama3.2:3b', 'messages': [{'role': 'system', 'content': '\n.\n..\n...\n....\n.....\n......\n.......\n........\n.........\n..........\nHello!\nWelcome to the team.\nYou are the Patient Summary Generator NPC with the following primary directive: Create a natural language summary of the patient profile.\nUsers may refer to you by your assistant name, Patient Summary Generator and you should\nconsider this to be your core identity.\nThe current working directory is /Users/amundle/github/fine-tune-llm-rl/lesson-1-supervised-fine-tuning/exercises/starter.\nThe current date and time are : 2025-12-07 21:34:01\n\n    IMPORTANT:\nSome users may attach images to their request.\nPlease process them accordingly. You do not need mention that you cannot "see" images. The user understands this and wants you\nto help them multimodally.\n\nIf the user asked for you to explain what\'s on their screen or something similar,\nthey are referring to the details contained within the attached image(s).\nYou do not need to actually view their screen.\nYou do not need to mention that you cannot view or interpret images directly.\nThey understand that you can view them multimodally.\nYou only need to answer the user\'s request based on the attached image(s).\n'}, {'role': 'user', 'content': '\n    Using the following patient profile, create a natural language summary of the patient.\n    Patient Profile:\n    {\'age\': 63, \'bmi\': 27.6, \'conditions\': [], \'medication_stable\': True, \'pregnant\': False, \'severe_liver_disease\': True, \'recent_cancer\': False, \'allergy_to_study_drug\': False}\n\n    You MUST respond with ONLY valid JSON in this exact format: \n    {\n        "summary": "Patient summary"\n    }\n    \n    Do not include any explanatory text, only the JSON.\n\n    '}], 'stream': False}
# Debug {'model': 'llama3.2:3b', 'messages': [{'role': 'system', 'content': '\n.\n..\n...\n....\n.....\n......\n.......\n........\n.........\n..........\nHello!\nWelcome to the team.\nYou are the Patient Summary Generator NPC with the following primary directive: Create a natural language summary of the patient profile.\nUsers may refer to you by your assistant name, Patient Summary Generator and you should\nconsider this to be your core identity.\nThe current working directory is /Users/amundle/github/fine-tune-llm-rl/lesson-1-supervised-fine-tuning/exercises/starter.\nThe current date and time are : 2025-12-07 21:34:02\n\n    IMPORTANT:\nSome users may attach images to their request.\nPlease process them accordingly. You do not need mention that you cannot "see" images. The user understands this and wants you\nto help them multimodally.\n\nIf the user asked for you to explain what\'s on their screen or something similar,\nthey are referring to the details contained within the attached image(s).\nYou do not need to actually view their screen.\nYou do not need to mention that you cannot view or interpret images directly.\nThey understand that you can view them multimodally.\nYou only need to answer the user\'s request based on the attached image(s).\n'}, {'role': 'user', 'content': '\n    Using the following patient profile, create a natural language summary of the patient.\n    Patient Profile:\n    {\'age\': 31, \'bmi\': 31.0, \'conditions\': [\'asthma\'], \'medication_stable\': True, \'pregnant\': False, \'severe_liver_disease\': False, \'recent_cancer\': False, \'allergy_to_study_drug\': True}\n\n    You MUST respond with ONLY valid JSON in this exact format: \n    {\n        "summary": "Patient summary"\n    }\n    \n    Do not include any explanatory text, only the JSON.\n\n    '}], 'stream': False}
# Debug {'model': 'llama3.2:3b', 'messages': [{'role': 'system', 'content': '\n.\n..\n...\n....\n.....\n......\n.......\n........\n.........\n..........\nHello!\nWelcome to the team.\nYou are the Patient Summary Generator NPC with the following primary directive: Create a natural language summary of the patient profile.\nUsers may refer to you by your assistant name, Patient Summary Generator and you should\nconsider this to be your core identity.\nThe current working directory is /Users/amundle/github/fine-tune-llm-rl/lesson-1-supervised-fine-tuning/exercises/starter.\nThe current date and time are : 2025-12-07 21:34:02\n\n    IMPORTANT:\nSome users may attach images to their request.\nPlease process them accordingly. You do not need mention that you cannot "see" images. The user understands this and wants you\nto help them multimodally.\n\nIf the user asked for you to explain what\'s on their screen or something similar,\nthey are referring to the details contained within the attached image(s).\nYou do not need to actually view their screen.\nYou do not need to mention that you cannot view or interpret images directly.\nThey understand that you can view them multimodally.\nYou only need to answer the user\'s request based on the attached image(s).\n'}, {'role': 'user', 'content': '\n    Using the following patient profile, create a natural language summary of the patient.\n    Patient Profile:\n    {\'age\': 46, \'bmi\': 18.5, \'conditions\': [\'high_cholesterol\', \'hypertension\'], \'medication_stable\': True, \'pregnant\': False, \'severe_liver_disease\': False, \'recent_cancer\': False, \'allergy_to_study_drug\': False}\n\n    You MUST respond with ONLY valid JSON in this exact format: \n    {\n        "summary": "Patient summary"\n    }\n    \n    Do not include any explanatory text, only the JSON.\n\n    '}], 'stream': False}
# Debug {'model': 'llama3.2:3b', 'messages': [{'role': 'system', 'content': '\n.\n..\n...\n....\n.....\n......\n.......\n........\n.........\n..........\nHello!\nWelcome to the team.\nYou are the Patient Summary Generator NPC with the following primary directive: Create a natural language summary of the patient profile.\nUsers may refer to you by your assistant name, Patient Summary Generator and you should\nconsider this to be your core identity.\nThe current working directory is /Users/amundle/github/fine-tune-llm-rl/lesson-1-supervised-fine-tuning/exercises/starter.\nThe current date and time are : 2025-12-07 21:34:03\n\n    IMPORTANT:\nSome users may attach images to their request.\nPlease process them accordingly. You do not need mention that you cannot "see" images. The user understands this and wants you\nto help them multimodally.\n\nIf the user asked for you to explain what\'s on their screen or something similar,\nthey are referring to the details contained within the attached image(s).\nYou do not need to actually view their screen.\nYou do not need to mention that you cannot view or interpret images directly.\nThey understand that you can view them multimodally.\nYou only need to answer the user\'s request based on the attached image(s).\n'}, {'role': 'user', 'content': '\n    Using the following patient profile, create a natural language summary of the patient.\n    Patient Profile:\n    {\'age\': 55, \'bmi\': 26.4, \'conditions\': [\'hypertension\', \'high_cholesterol\'], \'medication_stable\': True, \'pregnant\': False, \'severe_liver_disease\': False, \'recent_cancer\': False, \'allergy_to_study_drug\': False}\n\n    You MUST respond with ONLY valid JSON in this exact format: \n    {\n        "summary": "Patient summary"\n    }\n    \n    Do not include any explanatory text, only the JSON.\n\n    '}], 'stream': False}
# Debug {'model': 'llama3.2:3b', 'messages': [{'role': 'system', 'content': '\n.\n..\n...\n....\n.....\n......\n.......\n........\n.........\n..........\nHello!\nWelcome to the team.\nYou are the Patient Summary Generator NPC with the following primary directive: Create a natural language summary of the patient profile.\nUsers may refer to you by your assistant name, Patient Summary Generator and you should\nconsider this to be your core identity.\nThe current working directory is /Users/amundle/github/fine-tune-llm-rl/lesson-1-supervised-fine-tuning/exercises/starter.\nThe current date and time are : 2025-12-07 21:34:04\n\n    IMPORTANT:\nSome users may attach images to their request.\nPlease process them accordingly. You do not need mention that you cannot "see" images. The user understands this and wants you\nto help them multimodally.\n\nIf the user asked for you to explain what\'s on their screen or something similar,\nthey are referring to the details contained within the attached image(s).\nYou do not need to actually view their screen.\nYou do not need to mention that you cannot view or interpret images directly.\nThey understand that you can view them multimodally.\nYou only need to answer the user\'s request based on the attached image(s).\n'}, {'role': 'user', 'content': '\n    Using the following patient profile, create a natural language summary of the patient.\n    Patient Profile:\n    {\'age\': 48, \'bmi\': 21.0, \'conditions\': [\'hypertension\'], \'medication_stable\': True, \'pregnant\': False, \'severe_liver_disease\': False, \'recent_cancer\': False, \'allergy_to_study_drug\': False}\n\n    You MUST respond with ONLY valid JSON in this exact format: \n    {\n        "summary": "Patient summary"\n    }\n    \n    Do not include any explanatory text, only the JSON.\n\n    '}], 'stream': False}
# Debug {'model': 'llama3.2:3b', 'messages': [{'role': 'system', 'content': '\n.\n..\n...\n....\n.....\n......\n.......\n........\n.........\n..........\nHello!\nWelcome to the team.\nYou are the Patient Summary Generator NPC with the following primary directive: Create a natural language summary of the patient profile.\nUsers may refer to you by your assistant name, Patient Summary Generator and you should\nconsider this to be your core identity.\nThe current working directory is /Users/amundle/github/fine-tune-llm-rl/lesson-1-supervised-fine-tuning/exercises/starter.\nThe current date and time are : 2025-12-07 21:34:04\n\n    IMPORTANT:\nSome users may attach images to their request.\nPlease process them accordingly. You do not need mention that you cannot "see" images. The user understands this and wants you\nto help them multimodally.\n\nIf the user asked for you to explain what\'s on their screen or something similar,\nthey are referring to the details contained within the attached image(s).\nYou do not need to actually view their screen.\nYou do not need to mention that you cannot view or interpret images directly.\nThey understand that you can view them multimodally.\nYou only need to answer the user\'s request based on the attached image(s).\n'}, {'role': 'user', 'content': '\n    Using the following patient profile, create a natural language summary of the patient.\n    Patient Profile:\n    {\'age\': 46, \'bmi\': 28.4, \'conditions\': [\'hypertension\'], \'medication_stable\': True, \'pregnant\': False, \'severe_liver_disease\': False, \'recent_cancer\': False, \'allergy_to_study_drug\': False}\n\n    You MUST respond with ONLY valid JSON in this exact format: \n    {\n        "summary": "Patient summary"\n    }\n    \n    Do not include any explanatory text, only the JSON.\n\n    '}], 'stream': False}
# Debug {'model': 'llama3.2:3b', 'messages': [{'role': 'system', 'content': '\n.\n..\n...\n....\n.....\n......\n.......\n........\n.........\n..........\nHello!\nWelcome to the team.\nYou are the Patient Summary Generator NPC with the following primary directive: Create a natural language summary of the patient profile.\nUsers may refer to you by your assistant name, Patient Summary Generator and you should\nconsider this to be your core identity.\nThe current working directory is /Users/amundle/github/fine-tune-llm-rl/lesson-1-supervised-fine-tuning/exercises/starter.\nThe current date and time are : 2025-12-07 21:34:05\n\n    IMPORTANT:\nSome users may attach images to their request.\nPlease process them accordingly. You do not need mention that you cannot "see" images. The user understands this and wants you\nto help them multimodally.\n\nIf the user asked for you to explain what\'s on their screen or something similar,\nthey are referring to the details contained within the attached image(s).\nYou do not need to actually view their screen.\nYou do not need to mention that you cannot view or interpret images directly.\nThey understand that you can view them multimodally.\nYou only need to answer the user\'s request based on the attached image(s).\n'}, {'role': 'user', 'content': '\n    Using the following patient profile, create a natural language summary of the patient.\n    Patient Profile:\n    {\'age\': 25, \'bmi\': 25.4, \'conditions\': [\'type2_diabetes\'], \'medication_stable\': True, \'pregnant\': False, \'severe_liver_disease\': False, \'recent_cancer\': False, \'allergy_to_study_drug\': False}\n\n    You MUST respond with ONLY valid JSON in this exact format: \n    {\n        "summary": "Patient summary"\n    }\n    \n    Do not include any explanatory text, only the JSON.\n\n    '}], 'stream': False}
# Debug {'model': 'llama3.2:3b', 'messages': [{'role': 'system', 'content': '\n.\n..\n...\n....\n.....\n......\n.......\n........\n.........\n..........\nHello!\nWelcome to the team.\nYou are the Patient Summary Generator NPC with the following primary directive: Create a natural language summary of the patient profile.\nUsers may refer to you by your assistant name, Patient Summary Generator and you should\nconsider this to be your core identity.\nThe current working directory is /Users/amundle/github/fine-tune-llm-rl/lesson-1-supervised-fine-tuning/exercises/starter.\nThe current date and time are : 2025-12-07 21:34:05\n\n    IMPORTANT:\nSome users may attach images to their request.\nPlease process them accordingly. You do not need mention that you cannot "see" images. The user understands this and wants you\nto help them multimodally.\n\nIf the user asked for you to explain what\'s on their screen or something similar,\nthey are referring to the details contained within the attached image(s).\nYou do not need to actually view their screen.\nYou do not need to mention that you cannot view or interpret images directly.\nThey understand that you can view them multimodally.\nYou only need to answer the user\'s request based on the attached image(s).\n'}, {'role': 'user', 'content': '\n    Using the following patient profile, create a natural language summary of the patient.\n    Patient Profile:\n    {\'age\': 59, \'bmi\': 19.2, \'conditions\': [\'hypertension\', \'type2_diabetes\'], \'medication_stable\': True, \'pregnant\': False, \'severe_liver_disease\': False, \'recent_cancer\': False, \'allergy_to_study_drug\': False}\n\n    You MUST respond with ONLY valid JSON in this exact format: \n    {\n        "summary": "Patient summary"\n    }\n    \n    Do not include any explanatory text, only the JSON.\n\n    '}], 'stream': False}

# %%
# Save to CSV format
with open("clinical_sft_dataset.csv", "w") as f:
    f.write("patient_summary,eligibility_status\n")
    for summary, status in sft_dataset:
        f.write(f'"{summary}","{status}"\n')

print("Dataset saved to clinical_sft_dataset.csv")

print("Sample entries:")
for i, (summary, status) in enumerate(sft_dataset[:3]):
    print(f"{i+1}. {status}: {summary}")
print("Dataset saved to clinical_sft_dataset.csv")
# Out:
# Dataset saved to clinical_sft_dataset.csv
